# %%
import pandas as pd


pd.options.mode.chained_assignment = None

dataframe = pd.read_csv('data/owid_covid_data_top10.csv', sep=',', encoding='utf8')
dataframe.head()
# Out:
#   iso_code      continent location        date  total_cases  new_cases  \
# 0      BRA  South America   Brazil  2020-02-26          1.0        1.0
# 1      BRA  South America   Brazil  2020-02-27          1.0        0.0
# 2      BRA  South America   Brazil  2020-02-28          1.0        0.0
# 3      BRA  South America   Brazil  2020-02-29          2.0        1.0
# 4      BRA  South America   Brazil  2020-03-01          2.0        0.0
#
#    new_cases_smoothed  total_deaths  new_deaths  new_deaths_smoothed  ...  \
# 0                 NaN           NaN         NaN                  NaN  ...
# 1                 NaN           NaN         NaN                  NaN  ...
# 2                 NaN           NaN         NaN                  NaN  ...
# 3                 NaN           NaN         NaN                  NaN  ...
# 4                 NaN           NaN         NaN                  NaN  ...
#
#    female_smokers  male_smokers  handwashing_facilities  \
# ...

# %%
dataframe['location'].value_counts()
# Out:
# location
# Japan             774
# South Korea       774
# United States     774
# France            772
# Germany           769
# India             766
# Italy             765
# Russia            765
# United Kingdom    765
# Brazil            739
# Name: count, dtype: int64

# %%
dataframe['location'].value_counts(dropna=True).sort_index()
# Out:
# location
# Brazil            739
# France            772
# Germany           769
# India             766
# Italy             765
# Japan             774
# Russia            765
# South Korea       774
# United Kingdom    765
# United States     774
# Name: count, dtype: int64

# %%
dataframe['location'].value_counts(normalize=True).sort_index()
# Out:
# location
# Brazil            0.096437
# France            0.100744
# Germany           0.100352
# India             0.099961
# Italy             0.099830
# Japan             0.101005
# Russia            0.099830
# South Korea       0.101005
# United Kingdom    0.099830
# United States     0.101005
# Name: proportion, dtype: float64

# %%
dataframe.sort_values(by=['new_cases'], ascending=False)
# Out:
#      iso_code      continent        location        date  total_cases  \
# 7608      USA  North America   United States  2022-01-10   61698165.0
# 7616      USA  North America   United States  2022-01-18   67714789.0
# 7601      USA  North America   United States  2022-01-03   56345482.0
# 7617      USA  North America   United States  2022-01-19   68713434.0
# 7610      USA  North America   United States  2022-01-12   63377110.0
# ...       ...            ...             ...         ...          ...
# 6558      GBR         Europe  United Kingdom  2021-04-09    4369510.0
# 6597      GBR         Europe  United Kingdom  2021-05-18    4454449.0
# 6855      GBR         Europe  United Kingdom  2022-01-31   17357576.0
# 6888      GBR         Europe  United Kingdom  2022-03-05   19172095.0
# 6889      USA  North America   United States  2020-01-22          1.0
#
#       new_cases  new_cases_smoothed  total_deaths  new_deaths  \
# 7608  1368167.0          764669.000      842623.0      1977.0
# ...

# %%
dataframe[dataframe['date'] == '2022-03-01'].sort_values(by=['new_deaths'], ascending=False)
# Out:
#      iso_code      continent        location        date  total_cases  \
# 7658      USA  North America   United States  2022-03-01   79091361.0
# 5345      RUS         Europe          Russia  2022-03-01   16257688.0
# 6884      GBR         Europe  United Kingdom  2022-03-01   19036570.0
# 734       BRA  South America          Brazil  2022-03-01   28818850.0
# 4580      JPN           Asia           Japan  2022-03-01    5071249.0
# 3806      ITA         Europe           Italy  2022-03-01   12829972.0
# 3041      IND           Asia           India  2022-03-01   42938599.0
# 1506      FRA         Europe          France  2022-03-01   22835320.0
# 6119      KOR           Asia     South Korea  2022-03-01    3492686.0
# 2275      DEU         Europe         Germany  2022-03-01   14974722.0
#
#       new_cases  new_cases_smoothed  total_deaths  new_deaths  \
# 7658    47031.0           62331.429      952423.0      1691.0
# 5345    96092.0          118164.000      345427.0       772.0
# ...

# %%
dataframe.iloc[:, 2:5]
# Out:
#            location        date  total_cases
# 0            Brazil  2020-02-26          1.0
# 1            Brazil  2020-02-27          1.0
# 2            Brazil  2020-02-28          1.0
# 3            Brazil  2020-02-29          2.0
# 4            Brazil  2020-03-01          2.0
# ...             ...         ...          ...
# 7658  United States  2022-03-01   79091361.0
# 7659  United States  2022-03-02   79143716.0
# 7660  United States  2022-03-03   79196008.0
# 7661  United States  2022-03-04   79250509.0
# 7662  United States  2022-03-05   79265726.0
#
# [7663 rows x 3 columns]

# %%
dataframe.loc[:, ['location', 'date', 'total_cases']]
# Out:
#            location        date  total_cases
# 0            Brazil  2020-02-26          1.0
# 1            Brazil  2020-02-27          1.0
# 2            Brazil  2020-02-28          1.0
# 3            Brazil  2020-02-29          2.0
# 4            Brazil  2020-03-01          2.0
# ...             ...         ...          ...
# 7658  United States  2022-03-01   79091361.0
# 7659  United States  2022-03-02   79143716.0
# 7660  United States  2022-03-03   79196008.0
# 7661  United States  2022-03-04   79250509.0
# 7662  United States  2022-03-05   79265726.0
#
# [7663 rows x 3 columns]

# %%
filtered_dataframe = dataframe.loc[:, ['location', 'date', 'total_cases']]
filtered_dataframe.head()
# Out:
#   location        date  total_cases
# 0   Brazil  2020-02-26          1.0
# 1   Brazil  2020-02-27          1.0
# 2   Brazil  2020-02-28          1.0
# 3   Brazil  2020-02-29          2.0
# 4   Brazil  2020-03-01          2.0

# %%
filtered_dataframe.set_index('location', inplace=True)
filtered_dataframe.head()
# Out:
#                 date  total_cases
# location
# Brazil    2020-02-26          1.0
# Brazil    2020-02-27          1.0
# Brazil    2020-02-28          1.0
# Brazil    2020-02-29          2.0
# Brazil    2020-03-01          2.0

# %%
brazil_dataframe = dataframe[dataframe['location'] == 'Brazil']
brazil_dataframe.head()
# Out:
#   iso_code      continent location        date  total_cases  new_cases  \
# 0      BRA  South America   Brazil  2020-02-26          1.0        1.0
# 1      BRA  South America   Brazil  2020-02-27          1.0        0.0
# 2      BRA  South America   Brazil  2020-02-28          1.0        0.0
# 3      BRA  South America   Brazil  2020-02-29          2.0        1.0
# 4      BRA  South America   Brazil  2020-03-01          2.0        0.0
#
#    new_cases_smoothed  total_deaths  new_deaths  new_deaths_smoothed  ...  \
# 0                 NaN           NaN         NaN                  NaN  ...
# 1                 NaN           NaN         NaN                  NaN  ...
# 2                 NaN           NaN         NaN                  NaN  ...
# 3                 NaN           NaN         NaN                  NaN  ...
# 4                 NaN           NaN         NaN                  NaN  ...
#
#    female_smokers  male_smokers  handwashing_facilities  \
# ...

# %%
dataframe[(dataframe['location'] == 'Brazil') & (dataframe['total_cases'] >= 10 ** 7)].head()
# alternatively:
# brazil_dataframe[brazil_dataframe['total_cases'] >= 10 ** 7].head()
# Out:
#     iso_code      continent location        date  total_cases  new_cases  \
# 358      BRA  South America   Brazil  2021-02-18   10039804.0    53479.0
# 359      BRA  South America   Brazil  2021-02-19   10091961.0    52157.0
# 360      BRA  South America   Brazil  2021-02-20   10144332.0    52371.0
# 361      BRA  South America   Brazil  2021-02-21   10173817.0    29485.0
# 362      BRA  South America   Brazil  2021-02-22   10205663.0    31846.0
#
#      new_cases_smoothed  total_deaths  new_deaths  new_deaths_smoothed  ...  \
# 358           45188.143      243752.0      1439.0             1032.714  ...
# 359           45647.429      245083.0      1331.0             1048.571  ...
# 360           46721.000      246114.0      1031.0             1049.429  ...
# 361           46544.143      246720.0       606.0             1042.714  ...
# 362           47406.714      247431.0       711.0             1057.000  ...
#
#      female_smokers  male_smokers  handwashing_facilities  \
# ...

# %%
dataframe[dataframe['iso_code'].isin(['BRA', 'USA'])].reset_index(drop=True)
# Out:
#      iso_code      continent       location        date  total_cases  \
# 0         BRA  South America         Brazil  2020-02-26          1.0
# 1         BRA  South America         Brazil  2020-02-27          1.0
# 2         BRA  South America         Brazil  2020-02-28          1.0
# 3         BRA  South America         Brazil  2020-02-29          2.0
# 4         BRA  South America         Brazil  2020-03-01          2.0
# ...       ...            ...            ...         ...          ...
# 1508      USA  North America  United States  2022-03-01   79091361.0
# 1509      USA  North America  United States  2022-03-02   79143716.0
# 1510      USA  North America  United States  2022-03-03   79196008.0
# 1511      USA  North America  United States  2022-03-04   79250509.0
# 1512      USA  North America  United States  2022-03-05   79265726.0
#
#       new_cases  new_cases_smoothed  total_deaths  new_deaths  \
# 0           1.0                 NaN           NaN         NaN
# ...

# %%
brazil_dataframe.loc[:, 'new_cases_percentage'] = brazil_dataframe['new_cases'] / brazil_dataframe['total_cases'] * 100

brazil_dataframe.head()
# Out:
#   iso_code      continent location        date  total_cases  new_cases  \
# 0      BRA  South America   Brazil  2020-02-26          1.0        1.0
# 1      BRA  South America   Brazil  2020-02-27          1.0        0.0
# 2      BRA  South America   Brazil  2020-02-28          1.0        0.0
# 3      BRA  South America   Brazil  2020-02-29          2.0        1.0
# 4      BRA  South America   Brazil  2020-03-01          2.0        0.0
#
#    new_cases_smoothed  total_deaths  new_deaths  new_deaths_smoothed  ...  \
# 0                 NaN           NaN         NaN                  NaN  ...
# 1                 NaN           NaN         NaN                  NaN  ...
# 2                 NaN           NaN         NaN                  NaN  ...
# 3                 NaN           NaN         NaN                  NaN  ...
# 4                 NaN           NaN         NaN                  NaN  ...
#
#    male_smokers  handwashing_facilities  hospital_beds_per_thousand  \
# ...

# %%
import numpy as np


brazil_dataframe.loc[:, 'log_total_cases'] = np.log(brazil_dataframe['total_cases'])

brazil_dataframe.head()
# Out:
#   iso_code      continent location        date  total_cases  new_cases  \
# 0      BRA  South America   Brazil  2020-02-26          1.0        1.0
# 1      BRA  South America   Brazil  2020-02-27          1.0        0.0
# 2      BRA  South America   Brazil  2020-02-28          1.0        0.0
# 3      BRA  South America   Brazil  2020-02-29          2.0        1.0
# 4      BRA  South America   Brazil  2020-03-01          2.0        0.0
#
#    new_cases_smoothed  total_deaths  new_deaths  new_deaths_smoothed  ...  \
# 0                 NaN           NaN         NaN                  NaN  ...
# 1                 NaN           NaN         NaN                  NaN  ...
# 2                 NaN           NaN         NaN                  NaN  ...
# 3                 NaN           NaN         NaN                  NaN  ...
# 4                 NaN           NaN         NaN                  NaN  ...
#
#    handwashing_facilities  hospital_beds_per_thousand  life_expectancy  \
# ...

# %%
new_cases = brazil_dataframe['new_cases']
brazil_dataframe.loc[:, 'new_cases_demean'] = new_cases - new_cases.mean()

brazil_dataframe[['date', 'new_cases', 'new_cases_demean']]
# Out:
#            date  new_cases  new_cases_demean
# 0    2020-02-26        1.0     -39260.489824
# 1    2020-02-27        0.0     -39261.489824
# 2    2020-02-28        0.0     -39261.489824
# 3    2020-02-29        1.0     -39260.489824
# 4    2020-03-01        0.0     -39261.489824
# ..          ...        ...               ...
# 734  2022-03-01    22279.0     -16982.489824
# 735  2022-03-02    27645.0     -11616.489824
# 736  2022-03-03    60177.0      20915.510176
# 737  2022-03-04    71380.0      32118.510176
# 738  2022-03-05    62748.0      23486.510176
#
# [739 rows x 3 columns]

# %%
brazil_dataframe.loc[:, 'lower_location'] = brazil_dataframe['location'].str.lower()
brazil_dataframe.loc[:, 'upper_location'] = brazil_dataframe['location'].str.upper()
brazil_dataframe.head()
# Out:
#   iso_code      continent location        date  total_cases  new_cases  \
# 0      BRA  South America   Brazil  2020-02-26          1.0        1.0
# 1      BRA  South America   Brazil  2020-02-27          1.0        0.0
# 2      BRA  South America   Brazil  2020-02-28          1.0        0.0
# 3      BRA  South America   Brazil  2020-02-29          2.0        1.0
# 4      BRA  South America   Brazil  2020-03-01          2.0        0.0
#
#    new_cases_smoothed  total_deaths  new_deaths  new_deaths_smoothed  ...  \
# 0                 NaN           NaN         NaN                  NaN  ...
# 1                 NaN           NaN         NaN                  NaN  ...
# 2                 NaN           NaN         NaN                  NaN  ...
# 3                 NaN           NaN         NaN                  NaN  ...
# 4                 NaN           NaN         NaN                  NaN  ...
#
#    human_development_index  excess_mortality_cumulative_absolute  \
# ...

# %%
columns_to_keep = ['location', 'date', 'new_cases', 'new_cases_per_million']

# %%
br_dataframe = dataframe[dataframe['iso_code'] == 'BRA'][columns_to_keep]

br_dataframe.rename(columns={'date': 'year_month'}, inplace=True)
br_dataframe['year_month'] = br_dataframe['year_month'].str[:7]

br_dataframe.reset_index(drop=True, inplace=True)

br_dataframe.head()
# Out:
#   location year_month  new_cases  new_cases_per_million
# 0   Brazil    2020-02        1.0                  0.005
# 1   Brazil    2020-02        0.0                  0.000
# 2   Brazil    2020-02        0.0                  0.000
# 3   Brazil    2020-02        1.0                  0.005
# 4   Brazil    2020-03        0.0                  0.000

# %%
monthly_br_dataframe = br_dataframe.groupby(['location', 'year_month'], as_index=True).mean()

monthly_br_dataframe.head()
# Out:
#                         new_cases  new_cases_per_million
# location year_month
# Brazil   2020-02         0.500000               0.002500
#          2020-03       184.354839               0.861452
#          2020-04      2715.666667              12.690400
#          2020-05     13837.096774              64.661387
#          2020-06     31597.517241             147.656517

# %%
us_dataframe = dataframe[(dataframe['iso_code'] == 'USA') & (dataframe['new_cases'] > 0)][columns_to_keep]

us_dataframe.rename(columns={'date': 'year_month'}, inplace=True)
us_dataframe['year_month'] = us_dataframe['year_month'].str[:7]

us_dataframe.reset_index(drop=True, inplace=True)

us_dataframe.head()
# Out:
#         location year_month  new_cases  new_cases_per_million
# 0  United States    2020-01        1.0                  0.003
# 1  United States    2020-01        3.0                  0.009
# 2  United States    2020-01        1.0                  0.003
# 3  United States    2020-01        2.0                  0.006
# 4  United States    2020-02        3.0                  0.009

# %%
monthly_us_dataframe = us_dataframe.groupby(['location', 'year_month'], as_index=True).mean()

monthly_us_dataframe.head()
# Out:
#                              new_cases  new_cases_per_million
# location      year_month
# United States 2020-01         1.750000               0.005250
#               2020-02         2.428571               0.007286
#               2020-03      6195.290323              18.609226
#               2020-04     29444.100000              88.443333
#               2020-05     22969.967742              68.996452

# %%
merged_monthly_br_us_dataframe = pd.merge(monthly_br_dataframe, monthly_us_dataframe, on='year_month', suffixes=('_br', '_us'))
merged_monthly_br_us_dataframe.head()
# Out:
#             new_cases_br  new_cases_per_million_br  new_cases_us  \
# year_month
# 2020-02         0.500000                  0.002500      2.428571
# 2020-03       184.354839                  0.861452   6195.290323
# 2020-04      2715.666667                 12.690400  29444.100000
# 2020-05     13837.096774                 64.661387  22969.967742
# 2020-06     31597.517241                147.656517  28578.766667
#
#             new_cases_per_million_us
# year_month
# 2020-02                     0.007286
# 2020-03                    18.609226
# 2020-04                    88.443333
# 2020-05                    68.996452
# 2020-06                    85.844033
